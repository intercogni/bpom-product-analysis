# %%
# import all dependencies
import os
import pandas

# %%
# import raw csv dataset
file_path = '../data/raw/produk_olahan_full.csv'

dataframe = pandas.read_csv(
   '../data/raw/cek_bpom.csv', 
   encoding='unicode_escape')

dataframe.head()
# Out:
#   'type'                  'id'  \
# 0   'PO'  'MD 220948009400126'
# 1   'PO'  'MD 212282006700001'
# 2   'PO'  'MD 212282006800001'
# 3   'PO'  'MD 212282006400001'
# 4   'PO'  'MD 212282006600001'
#
#                                               'name'              'brand'  \
# 0  'Bahan Tambahan Pangan Campuran Perisa Lemon d...            'Merk: D'
# 1  'Anggur Merah Fortifikasi (Mengandung Alkohol ...  'Merk:   ORANG TUA'
# 2  'Anggur Merah Fortifikasi (Mengandung Alkohol ...    'Merk: ORANG TUA'
# 3  'Minuman Beralkohol Golongan B Beraroma Soju d...          'Merk: BAE'
# 4          'Whisky (Mengandung Alkohol ï¿½ 43% v/v)'         'Merk: DRUM'
#
#                                          'packaging'            'registrar'  \
# 0  'Kemasan: Botol Plastik HDPE  (60 ml dan 450 ml)'     'STEFANUS SUSANTO'
# 1  'Kemasan: Botol Kaca (180 ml, 250 ml, 275 ml, ...  'ASTI DAMA ADHIMUKTI'
# 2  'Kemasan: Botol Kaca (180 ml, 250 ml,  275 ml,...  'ASTI DAMA ADHIMUKTI'
# ...
